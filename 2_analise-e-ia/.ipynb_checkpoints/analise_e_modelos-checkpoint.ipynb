# %% [markdown]
# Autor: Hugo Martins
#
# Dataset: https://www.kaggle.com/nilimajauhari/glassdoor-analyze-gender-pay-gap
#
# Descrição do dataset:
#
# # Descrever dataset

# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
glassdoor_data = pd.read_csv('glassdoor_gender_pay_gap.csv') # Leitura do dataset

# %% [markdown]
# # Dados contínuos

# %%
glassdoor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   JobTitle   1000 non-null   object
#  1   Gender     1000 non-null   object
#  2   Age        1000 non-null   int64
#  3   PerfEval   1000 non-null   int64
#  4   Education  1000 non-null   object
#  5   Dept       1000 non-null   object
#  6   Seniority  1000 non-null   int64
#  7   BasePay    1000 non-null   int64
#  8   Bonus      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
sns.histplot(glassdoor_data['Bonus'], bins=5)
# Out:
# <AxesSubplot:xlabel='Bonus', ylabel='Count'>

# %%
plt.rcParams['figure.figsize'] = [16, 4]

fig, ax = plt.subplots(1, 3)

ax[0].hist(glassdoor_data['Age'])
ax[0].set_title("Age")

ax[1].hist(glassdoor_data['BasePay'])
ax[1].set_title("BasePay")

ax[2].hist(glassdoor_data['Bonus'])
ax[2].set_title("Bonus")

plt.show()

# %%
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Analisando o gráfico acima, podemos observar que as variáveis que possuem maior correlação são, respectivamente:
#
# - Bonus e PerfEval
# - BasePay e Age
# - BasePay e PerfEval
# - BasePay e Seniority

# %%
sns.pairplot(df, hue="Gender");

# %% [markdown]
# # Dados categóricos
